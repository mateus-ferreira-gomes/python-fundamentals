# %% [markdown]
# <a href="https://colab.research.google.com/github/mateus-ferreira-gomes/python-fundamentals/blob/main/Atividade.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Atividade 1 Calculadora em python

# %%
def soma(a, b):
  return a + b

def subtracao(a, b):
  return a - b

def multiplicacao(a, b):
  return a * b

def divisao(a, b):
    if b == 0:
        return "Não é possível dividir por zero"
    return a / b

while True:
  print("\n===== CALCULADORA =====")
  print("1 - Soma")
  print("2 - Subtracao")
  print("3 - Multiplicacao")
  print("4 - Divisao")
  print("5 - Sair")

  opcao = input("Escolha uma opcao: ")

  if opcao == "0":
     print("Encerrando calculadora...")
     break
  if opcao in ["1", "2", "3", "4"]:
    try:
      num1 = float(input("Digite o primeiro numero: "))
      num2 = float(input("Digite o segundo numero: "))

      if opcao == "1":
          print("Resultado: ", soma(num1, num2))
      elif opcao == "2":
          print("Resultado: ", subtracao(num1, num2))
      elif opcao == "3":
          print("Resultado: ", multiplicacao(num1, num2))
      elif opcao == "4":
          print("Resultado: ", divisao(num1, num2))
    except ValueError:
        print("Erro: Digite apenas numeros validos!")
  else:
      print("Opcão inválida!")
# Out:
# ===== CALCULADORA =====
# 1 - Soma
# 2 - Subtracao
# 3 - Multiplicacao
# 4 - Divisao
# 5 - Sair
# Escolha uma opcao: 10
# Opcão inválida!
#
# ===== CALCULADORA =====
# 1 - Soma
# 2 - Subtracao
# 3 - Multiplicacao
# 4 - Divisao
# 5 - Sair
# Escolha uma opcao: 1
# Digite o primeiro numero: 10
# Digite o segundo numero: 10
# Resultado:  20.0
#
# ===== CALCULADORA =====
# 1 - Soma
# 2 - Subtracao
# 3 - Multiplicacao
# 4 - Divisao
# 5 - Sair
# Escolha uma opcao: 2
# Digite o primeiro numero: 2
# Digite o segundo numero: 2
# Resultado:  0.0
#
# ===== CALCULADORA =====
# 1 - Soma
# 2 - Subtracao
# 3 - Multiplicacao
# 4 - Divisao
# 5 - Sair
# Escolha uma opcao: 20
# Opcão inválida!
#
# ===== CALCULADORA =====
# 1 - Soma
# 2 - Subtracao
# 3 - Multiplicacao
# 4 - Divisao
# 5 - Sair
# Escolha uma opcao: 20
# Opcão inválida!
#
# ===== CALCULADORA =====
# 1 - Soma
# 2 - Subtracao
# 3 - Multiplicacao
# 4 - Divisao
# 5 - Sair
# Escolha uma opcao: 3
# Digite o primeiro numero: 3
# ...
